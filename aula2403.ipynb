# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizGustavoReis/am-t4-s1a2026/blob/main/aula2403.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=2
b=3
print("A soma é:", a+b)
# Out:
# A soma é: 5

# %% [markdown]
# ## Segunda camada

# %%
c=4
d=5
print("A multiplicação é:",c*d)
# Out:
# A multiplicação é: 20

# %% [markdown]
# # Bliblioteca e funções de Python

# %%
import math

def equacao2grau(a,b,c):
  delta = b**2 - 4*a*c

  if delta < 0:
    return 'Numero sem raiz',delta

  x1 =(-b + math.sqrt(delta))/(2*a)
  x2 =(-b - math.sqrt(delta))/(2*a)
  return x1, x2

# %% [markdown]
# ## Testes de Função Matemática

# %%
eq = equacao2grau(1 , -3 , 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a =random.randint(-5,5)
  b =random.randint(-10,10)
  c=random.randint(-10,10)

eq += equacao2grau(a , b , c)

# %%
for i in range(12):
  if i % 2 == 0:
    if (eq[i] != 'Numero sem raiz'):
     print('X1:[',f"{eq[i]:.2f}",']')
  else:
   print('X2:[',f"{eq[i]:.2f}",']\n')
# Out:
# X1:[ 2.00 ]
# X2:[ 1.00 ]
#
# X2:[ -56.00 ]
#
# X1:[ 0.68 ]
# X2:[ -5.18 ]
#
# X1:[ -1.22 ]
# X2:[ 0.55 ]
#
# X2:[ -96.00 ]
#
# X1:[ 0.30 ]
# X2:[ -3.30 ]

# %% [markdown]
# #Trabalho Com Dados Externos

# %% [markdown]
# ## Bibliotecas de uso da pipeline

# %%
# !pip -q install plotly
# !pip -q install yellowbrick

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matlib.pyplot as plt
import plotly.express as px
