# %% [markdown]
# <a href="https://colab.research.google.com/github/LuizGustavoReis/am-t4-s1a2026/blob/main/exercicio0428API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time

API_KEY = 'F49SXSWTFPRZY772'
EMPRESAS = ['NFLX','AAPL','GOOGL','AMZN','MSFT']
lista_emp = []

for simbolo in EMPRESAS:
  print(f'Extraindo dados de {simbolo}')
  time.sleep(5)
  url = f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={simbolo}&apikey={API_KEY}'
  r = requests.get(url)
  base = r.json()

  if 'Global Quote' in base:
    temporario = pd.DataFrame([base['Global Quote']])
    lista_emp.append(temporario)


base_empresas = pd.concat(lista_emp)
# Out:
# Extraindo dados de NFLX
# Extraindo dados de AAPL
# Extraindo dados de GOOGL
# Extraindo dados de AMZN
# Extraindo dados de MSFT

# %%
base_empresas
# Out:
#   01. symbol  02. open  03. high   04. low 05. price 06. volume  \
# 0       NFLX   92.0500   92.8400   91.3000   91.3700   29707439
# 0       AAPL  266.0900  268.3600  265.0700  267.6100   41466762
# 0      GOOGL  345.9800  353.1800  342.7300  350.3400   28576887
# 0       AMZN  263.4600  264.1500  260.3400  261.1200   44906840
# 0       MSFT  422.3750  427.1100  417.0701  424.8200   30867303
#
#   07. latest trading day 08. previous close 09. change 10. change percent
# 0             2026-04-27            92.4400    -1.0700           -1.1575%
# 0             2026-04-27           271.0600    -3.4500           -1.2728%
# 0             2026-04-27           344.4000     5.9400            1.7247%
# 0             2026-04-27           263.9900    -2.8700           -1.0872%
# 0             2026-04-27           424.6200     0.2000            0.0471%
